# %%
import pandas as pd

# %%
df=pd.read_csv('students_data_pandas.csv')
df.head(10)
# Out:
#    id    name  birth_date  age gender  maths  science  computer  total   avg  \
# 0   1   Aalok  17-01-2004   21      m     81     97.0        89    267  89.0
# 1   2    Riya  12-05-2003   22      f     78     85.0        91    254  84.6
# 2   3   Arjun  12-13-2004   20      m     88     92.0        95    275  91.6
# 3   4    Neha  01-08-2005   25      f     65     70.0        68    203  67.6
# 4   5   Kunal  30-11-2004   19      M     90     88.0        92    270  90.0
# 5   6   Priya         NaN   21      f     72     80.0        77    229  76.3
# 6   7   Rahul  17-01-2004   21    NaN     85     82.0        88    255  85.0
# 7   8   Sneha  2006-02-29   18      f     95    101.0        89    285  95.0
# 8   9   Varun  15-07-2003   22      m     60     55.0        58    173  57.6
# 9  10  Anjali  10-10-2005   20      f     78     82.0        80    240  80.0
#
#   percentage grade
# 0     89.00%     A
# 1     84.66%     B
# 2     91.66%     A
# 3     67.66%     C
# 4        90%     A
# ...

# %%
df.tail(10)
# Out:
#     id     name  birth_date  age gender  maths  science  computer  total  \
# 40  41   Naveen  09-09-2003   22      m     92     90.0        91    273
# 41  42  Pallavi  06-06-2004   21      f     74     76.0        78    228
# 42  43      Raj  01-01-2005   19      m     63     65.0        67    195
# 43  44      Ira  04-04-2004   21      f     87     88.0        89    264
# 44  45  Shubham  11-11-2003   22      m     55     58.0        60    173
# 45  46  Nandini  09-09-2005   19      f     90     92.0        94    276
# 46  47    Sumit  10-10-2004   21      m     80     82.0        84    246
# 47  48     Tara     invalid   20      f     68     70.0        72    210
# 48  49    Ayush  05-05-2003   22      m     86     88.0        90    264
# 49  50     Rhea  07-07-2004   21    NaN     75     78.0        80    233
#
#      avg percentage grade
# 40  91.0        91%     A
# 41  76.0        76%     B
# 42  65.0        65%     C
# 43  88.0        88%     A
# 44  57.6     57.66%     D
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          50 non-null     int64
#  1   name        50 non-null     object
#  2   birth_date  48 non-null     object
#  3   age         50 non-null     int64
#  4   gender      48 non-null     object
#  5   maths       50 non-null     int64
#  6   science     49 non-null     float64
#  7   computer    50 non-null     int64
#  8   total       50 non-null     int64
#  9   avg         50 non-null     float64
#  10  percentage  50 non-null     object
#  11  grade       50 non-null     object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 4.8+ KB

# %%
# Null value removal

# Date format check:
df['birth_date']=pd.to_datetime(df['birth_date'],format='mixed',errors='coerce')
df
# Out:
#     id     name birth_date  age gender  maths  science  computer  total   avg  \
# 0    1    Aalok 2004-01-17   21      m     81     97.0        89    267  89.0
# 1    2     Riya 2003-12-05   22      f     78     85.0        91    254  84.6
# 2    3    Arjun 2004-12-13   20      m     88     92.0        95    275  91.6
# 3    4     Neha 2005-01-08   25      f     65     70.0        68    203  67.6
# 4    5    Kunal 2004-11-30   19      M     90     88.0        92    270  90.0
# 5    6    Priya        NaT   21      f     72     80.0        77    229  76.3
# 6    7    Rahul 2004-01-17   21    NaN     85     82.0        88    255  85.0
# 7    8    Sneha        NaT   18      f     95    101.0        89    285  95.0
# 8    9    Varun 2003-07-15   22      m     60     55.0        58    173  57.6
# 9   10   Anjali 2005-10-10   20      f     78     82.0        80    240  80.0
# 10  11    Rohit        NaT   20      m     88     86.0        90    264  88.0
# ...

# %%
df[df['birth_date'].isna()]
# Out:
#     id   name birth_date  age gender  maths  science  computer  total   avg  \
# 5    6  Priya        NaT   21      f     72     80.0        77    229  76.3
# 7    8  Sneha        NaT   18      f     95    101.0        89    285  95.0
# 10  11  Rohit        NaT   20      m     88     86.0        90    264  88.0
# 11  12  Meera        NaT   21      f     70     72.0        75    217  72.3
# 18  19    Dev        NaT   20      m     90     91.0        89    270  90.0
# 22  23  Harsh        NaT   22      m     67     69.0        71    207  69.0
# 26  27  Akash        NaT   22      m     88     90.0        92    270  90.0
# 32  33     Om        NaT   21      m     77     79.0        78    234  78.0
# 35  36  Reena        NaT   20      f     73     75.0        74    222  74.0
# 38  39  Karan        NaT   21      m     69     71.0        70    210  70.0
# 47  48   Tara        NaT   20      f     68     70.0        72    210  70.0
#
#    percentage grade
# 5      76.33%     B
# ...

# %%
# average age of students:
df['age'].mean()
# Out:
# 20.74

# %%
df['age'].median()
# Out:
# 21.0

# %%
df['age'].mode()
# Majority of students are of age 21 so we will replace the Null birth date with 20-11-2004
# Out:
# 0    21
# Name: age, dtype: int64

# %%
df['birth_date']=df['birth_date'].fillna('20-11-2004')

# %%
df
# Out:
#     id     name birth_date  age gender  maths  science  computer  total   avg  \
# 0    1    Aalok 2004-01-17   21      m     81     97.0        89    267  89.0
# 1    2     Riya 2003-12-05   22      f     78     85.0        91    254  84.6
# 2    3    Arjun 2004-12-13   20      m     88     92.0        95    275  91.6
# 3    4     Neha 2005-01-08   25      f     65     70.0        68    203  67.6
# 4    5    Kunal 2004-11-30   19      M     90     88.0        92    270  90.0
# 5    6    Priya 2004-11-20   21      f     72     80.0        77    229  76.3
# 6    7    Rahul 2004-01-17   21    NaN     85     82.0        88    255  85.0
# 7    8    Sneha 2004-11-20   18      f     95    101.0        89    285  95.0
# 8    9    Varun 2003-07-15   22      m     60     55.0        58    173  57.6
# 9   10   Anjali 2005-10-10   20      f     78     82.0        80    240  80.0
# 10  11    Rohit 2004-11-20   20      m     88     86.0        90    264  88.0
# ...

# %%
df['gender'].mode()
# Out:
# 0    m
# Name: gender, dtype: object

# %%
df['gender']=df['gender'].fillna('m')

# %%
df
# Out:
#     id     name birth_date  age gender  maths  science  computer  total   avg  \
# 0    1    Aalok 2004-01-17   21      m     81     97.0        89    267  89.0
# 1    2     Riya 2003-12-05   22      f     78     85.0        91    254  84.6
# 2    3    Arjun 2004-12-13   20      m     88     92.0        95    275  91.6
# 3    4     Neha 2005-01-08   25      f     65     70.0        68    203  67.6
# 4    5    Kunal 2004-11-30   19      M     90     88.0        92    270  90.0
# 5    6    Priya 2004-11-20   21      f     72     80.0        77    229  76.3
# 6    7    Rahul 2004-01-17   21      m     85     82.0        88    255  85.0
# 7    8    Sneha 2004-11-20   18      f     95    101.0        89    285  95.0
# 8    9    Varun 2003-07-15   22      m     60     55.0        58    173  57.6
# 9   10   Anjali 2005-10-10   20      f     78     82.0        80    240  80.0
# 10  11    Rohit 2004-11-20   20      m     88     86.0        90    264  88.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          50 non-null     int64
#  1   name        50 non-null     object
#  2   birth_date  50 non-null     datetime64[ns]
#  3   age         50 non-null     int64
#  4   gender      50 non-null     object
#  5   maths       50 non-null     int64
#  6   science     49 non-null     float64
#  7   computer    50 non-null     int64
#  8   total       50 non-null     int64
#  9   avg         50 non-null     float64
#  10  percentage  50 non-null     object
#  11  grade       50 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(4)
# memory usage: 4.8+ KB

# %%
df['science']=df['science'].fillna(df['science'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          50 non-null     int64
#  1   name        50 non-null     object
#  2   birth_date  50 non-null     datetime64[ns]
#  3   age         50 non-null     int64
#  4   gender      50 non-null     object
#  5   maths       50 non-null     int64
#  6   science     50 non-null     float64
#  7   computer    50 non-null     int64
#  8   total       50 non-null     int64
#  9   avg         50 non-null     float64
#  10  percentage  50 non-null     object
#  11  grade       50 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(4)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#              id           birth_date       age       maths     science  \
# count  50.00000                   50  50.00000   50.000000   50.000000
# mean   25.50000  2004-08-25 20:38:24  20.74000   76.960000   80.880000
# min     1.00000  2003-01-15 00:00:00  17.00000   -5.000000   50.000000
# 25%    13.25000  2004-01-17 00:00:00  20.00000   69.250000   72.750000
# 50%    25.50000  2004-11-20 00:00:00  21.00000   80.500000   83.000000
# 75%    37.75000  2004-12-16 18:00:00  21.00000   88.000000   89.000000
# max    50.00000  2006-10-09 00:00:00  30.00000  100.000000  101.000000
# std    14.57738                  NaN   1.94632   16.966907   11.865986
#
#         computer       total        avg
# count  50.000000   50.000000  50.000000
# mean   79.540000  235.720000  78.554000
# min   -10.000000  143.000000  47.600000
# 25%    71.250000  210.000000  70.000000
# 50%    83.000000  246.000000  82.000000
# 75%    90.000000  269.250000  89.750000
# max    99.000000  297.000000  99.000000
# ...

# %%
print(df.to_string())
# Out:
#     id     name birth_date  age gender  maths  science  computer  total   avg percentage grade
# 0    1    Aalok 2004-01-17   21      m     81     97.0        89    267  89.0     89.00%     A
# 1    2     Riya 2003-12-05   22      f     78     85.0        91    254  84.6     84.66%     B
# 2    3    Arjun 2004-12-13   20      m     88     92.0        95    275  91.6     91.66%     A
# 3    4     Neha 2005-01-08   25      f     65     70.0        68    203  67.6     67.66%     C
# 4    5    Kunal 2004-11-30   19      M     90     88.0        92    270  90.0        90%     A
# 5    6    Priya 2004-11-20   21      f     72     80.0        77    229  76.3     76.33%     B
# 6    7    Rahul 2004-01-17   21      m     85     82.0        88    255  85.0        85%     B
# 7    8    Sneha 2004-11-20   18      f     95    101.0        89    285  95.0        95%     A
# 8    9    Varun 2003-07-15   22      m     60     55.0        58    173  57.6     57.66%     D
# ...

# %%
for i in df.index:
    if df.loc[i,'maths']>100 or df.loc[i,'maths']<0:
        df.drop(index=i, inplace=True)

# %%
df
# Out:
#     id     name birth_date  age gender  maths  science  computer  total   avg  \
# 0    1    Aalok 2004-01-17   21      m     81     97.0        89    267  89.0
# 1    2     Riya 2003-12-05   22      f     78     85.0        91    254  84.6
# 2    3    Arjun 2004-12-13   20      m     88     92.0        95    275  91.6
# 3    4     Neha 2005-01-08   25      f     65     70.0        68    203  67.6
# 4    5    Kunal 2004-11-30   19      M     90     88.0        92    270  90.0
# 5    6    Priya 2004-11-20   21      f     72     80.0        77    229  76.3
# 6    7    Rahul 2004-01-17   21      m     85     82.0        88    255  85.0
# 7    8    Sneha 2004-11-20   18      f     95    101.0        89    285  95.0
# 8    9    Varun 2003-07-15   22      m     60     55.0        58    173  57.6
# 9   10   Anjali 2005-10-10   20      f     78     82.0        80    240  80.0
# 10  11    Rohit 2004-11-20   20      m     88     86.0        90    264  88.0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in df.index:
    if df.loc[i,'science']>100 or df.loc[i,'science']<0:
        df.drop(index=i, inplace=True)

# %%
for i in df.index:
    if df.loc[i,'computer']>100 or df.loc[i,'computer']<0:
        df.drop(index=i, inplace=True)

# %%
df
# Out:
#     id     name birth_date  age gender  maths  science  computer  total   avg  \
# 0    1    Aalok 2004-01-17   21      m     81     97.0        89    267  89.0
# 1    2     Riya 2003-12-05   22      f     78     85.0        91    254  84.6
# 2    3    Arjun 2004-12-13   20      m     88     92.0        95    275  91.6
# 3    4     Neha 2005-01-08   25      f     65     70.0        68    203  67.6
# 4    5    Kunal 2004-11-30   19      M     90     88.0        92    270  90.0
# 5    6    Priya 2004-11-20   21      f     72     80.0        77    229  76.3
# 6    7    Rahul 2004-01-17   21      m     85     82.0        88    255  85.0
# 8    9    Varun 2003-07-15   22      m     60     55.0        58    173  57.6
# 9   10   Anjali 2005-10-10   20      f     78     82.0        80    240  80.0
# 10  11    Rohit 2004-11-20   20      m     88     86.0        90    264  88.0
# 11  12    Meera 2004-11-20   21      f     70     72.0        75    217  72.3
# ...

# %%
df.count()
# Out:
# id            47
# name          47
# birth_date    47
# age           47
# gender        47
# maths         47
# science       47
# computer      47
# total         47
# avg           47
# percentage    47
# grade         47
# dtype: int64

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     index  id     name birth_date  age gender  maths  science  computer  \
# 0       0   1    Aalok 2004-01-17   21      m     81     97.0        89
# 1       1   2     Riya 2003-12-05   22      f     78     85.0        91
# 2       2   3    Arjun 2004-12-13   20      m     88     92.0        95
# 3       3   4     Neha 2005-01-08   25      f     65     70.0        68
# 4       4   5    Kunal 2004-11-30   19      M     90     88.0        92
# 5       5   6    Priya 2004-11-20   21      f     72     80.0        77
# 6       6   7    Rahul 2004-01-17   21      m     85     82.0        88
# 7       8   9    Varun 2003-07-15   22      m     60     55.0        58
# 8       9  10   Anjali 2005-10-10   20      f     78     82.0        80
# 9      10  11    Rohit 2004-11-20   20      m     88     86.0        90
# 10     11  12    Meera 2004-11-20   21      f     70     72.0        75
# 11     12  13     Aman 2003-09-15   18      m     92     94.0        96
# ...

# %%
df['grade'].value_counts()
# Out:
# grade
# A    17
# B    14
# C    10
# D     5
# E     1
# Name: count, dtype: int64

# %%
df['result']=df['grade'].isin(['D','E']).map({True:'Fail',False:'Pass'})

# %%
df
# Out:
#     index  id     name birth_date  age gender  maths  science  computer  \
# 0       0   1    Aalok 2004-01-17   21      m     81     97.0        89
# 1       1   2     Riya 2003-12-05   22      f     78     85.0        91
# 2       2   3    Arjun 2004-12-13   20      m     88     92.0        95
# 3       3   4     Neha 2005-01-08   25      f     65     70.0        68
# 4       4   5    Kunal 2004-11-30   19      M     90     88.0        92
# 5       5   6    Priya 2004-11-20   21      f     72     80.0        77
# 6       6   7    Rahul 2004-01-17   21      m     85     82.0        88
# 7       8   9    Varun 2003-07-15   22      m     60     55.0        58
# 8       9  10   Anjali 2005-10-10   20      f     78     82.0        80
# 9      10  11    Rohit 2004-11-20   20      m     88     86.0        90
# 10     11  12    Meera 2004-11-20   21      f     70     72.0        75
# 11     12  13     Aman 2003-09-15   18      m     92     94.0        96
# ...

# %%
df['result'].value_counts()
# Out:
# result
# Pass    41
# Fail     6
# Name: count, dtype: int64

# %%
df['result'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['grade'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['gender']=df['gender'].str.lower()

# %%
df['gender'].value_counts()
# Out:
# gender
# m    25
# f    22
# Name: count, dtype: int64

# %%
print("Average marks in Maths: ",round(df['maths'].mean(),2))
print("Average marks in Science: ",round(df['science'].mean(),2))
print("Average marks in computer: ",round(df['computer'].mean(),2))
# Out:
# Average marks in Maths:  78.09
# Average marks in Science:  80.43
# Average marks in computer:  81.23

# %%
df.sort_values(by='percentage', ascending=False, inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.drop(columns=['index'],inplace=True)

# %%
df
# Out:
#     id     name birth_date  age gender  maths  science  computer  total   avg  \
# 0   25     Yash 2004-01-01   21      m    100     99.0        98    297  99.0
# 1   37    Parth 2003-01-15   22      m     95     97.0        99    291  97.0
# 2   22   Sakshi 2004-12-18   21      f     93     95.0        97    285  95.0
# 3   13     Aman 2003-09-15   18      m     92     94.0        96    282  94.0
# 4   46  Nandini 2005-09-09   19      f     90     92.0        94    276  92.0
# 5    3    Arjun 2004-12-13   20      m     88     92.0        95    275  91.6
# 6   41   Naveen 2003-09-09   22      m     92     90.0        91    273  91.0
# 7   30    Alina 2004-11-11   21      f     91     89.0        93    273  91.0
# 8   34    Kavya 2003-10-20   22      f     89     92.0        90    271  90.3
# 9   27    Akash 2004-11-20   22      m     88     90.0        92    270  90.0
# 10  19      Dev 2004-11-20   20      m     90     91.0        89    270  90.0
# ...

# %%
failed_students=df[df['result']=='Fail']

# %%
print(failed_students['name'])
# Out:
# 41      Manav
# 42    Shubham
# 43      Pooja
# 44      Varun
# 45       Tina
# 46      Payal
# Name: name, dtype: object

# %%
failed_students
# Out:
#     id     name birth_date  age gender  maths  science  computer  total   avg  \
# 41  35    Manav 2004-05-18   21      m     58     60.0        62    180  60.0
# 42  45  Shubham 2003-11-11   22      m     55     58.0        60    173  57.6
# 43  14    Pooja 2005-06-15   19      f     55     60.0        58    173  57.6
# 44   9    Varun 2003-07-15   22      m     60     55.0        58    173  57.6
# 45  20     Tina 2005-05-05   19      f     76     83.0        81    157  52.3
# 46  26    Payal 2006-10-09   17      f     45     50.0        48    143  47.6
#
#    percentage grade result
# 41        60%     D   Fail
# 42     57.66%     D   Fail
# 43     57.66%     D   Fail
# 44     57.66%     D   Fail
# 45     52.33%     D   Fail
# 46     47.66%     E   Fail

# %%
failed_students['grace_eligible']=failed_students['total']>170
# Out:
# /tmp/ipykernel_167/1612976171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   failed_students['grace_eligible']=failed_students['total']>170

# %%
failed_students
# Out:
#     id     name birth_date  age gender  maths  science  computer  total   avg  \
# 41  35    Manav 2004-05-18   21      m     58     60.0        62    180  60.0
# 42  45  Shubham 2003-11-11   22      m     55     58.0        60    173  57.6
# 43  14    Pooja 2005-06-15   19      f     55     60.0        58    173  57.6
# 44   9    Varun 2003-07-15   22      m     60     55.0        58    173  57.6
# 45  20     Tina 2005-05-05   19      f     76     83.0        81    157  52.3
# 46  26    Payal 2006-10-09   17      f     45     50.0        48    143  47.6
#
#    percentage grade result  grace_eligible
# 41        60%     D   Fail            True
# 42     57.66%     D   Fail            True
# 43     57.66%     D   Fail            True
# 44     57.66%     D   Fail            True
# 45     52.33%     D   Fail           False
# 46     47.66%     E   Fail           False
