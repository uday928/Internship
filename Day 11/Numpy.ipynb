# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5,6])
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
print(np.__version__)
# Out:
# 1.24.3

# %%
print(arr.ndim)
# to get the dimensions of array
# Out:
# 1

# %%
new=np.array([1,2,3,4],ndmin=5)
new
# Out:
# array([[[[[1, 2, 3, 4]]]]])

# %%
print(new.ndim)
# Out:
# 5

# %%
arr[0]
# Out:
# 1

# %%
arr[0]+arr[2]
# Out:
# 4

# %%
arr1=np.array([[1,2,3],[4,5,6]])
arr1[0,1]
# Out:
# 2

# %%
arr[:2]
# Out:
# array([1, 2])

# %%
print(arr[:5])
# Out:
# [1 2 3 4 5]

# %%
print(arr[1:5])
# in this case 1st index from start to 5th index from start where 5th index got ignored
# Out:
# [2 3 4 5]

# %%
print(arr[1:])
# Out:
# [2 3 4 5 6]

# %%
arr[-4:-1]
# in reverse slicing 4th index from end (2) to first index from end where -4th index got ignored
# in forward slicing ending index and in backward slicing starting index goes ignored
# Out:
# array([3, 4, 5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr[1:5:2]
# Out:
# array([2, 4])

# %%
arr[::2]
# Out:
# array([1, 3, 5])

# %%
arr1[1,0:]
# Out:
# array([4, 5, 6])

# %%
arr1[1,0:1]
# Out:
# array([4])

# %%
arr1[0:,1]
# Out:
# array([2, 5])

# %%
arr1[0:,1:]
# Out:
# array([[2, 3],
#        [5, 6]])

# %%
print(arr.dtype)
# Out:
# int64

# %%
s=np.array(['a','b'])
s
# Out:
# array(['a', 'b'], dtype='<U1')

# %%
s.dtype
# OP: U1 : where U is unicode string and 1 means 1 character size
# Out:
# dtype('<U1')

# %%
arr2=np.array([1,2,3,4],dtype='S')

# %%
arr2
# Out:
# array([b'1', b'2', b'3', b'4'], dtype='|S1')

# %%
arr3=np.array([1,2,3,4],dtype='i4')

# %%
arr3
# Out:
# array([1, 2, 3, 4], dtype=int32)

# %%
arr4=np.array(['1','a'],dtype='i')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 arr4=np.array(['1','a'],dtype='i')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
new2=np.array([1.1,1.2,1.4])
print(new2)
print(new2.dtype)
# Out:
# [1.1 1.2 1.4]
# float64

# %%
new2=new2.astype('i')

# %%
new2
# Out:
# array([1, 1, 1], dtype=int32)

# %%
new3=np.array([1,2,3,4,5.1,1.78])
print(new3)
print(new3.dtype)
# Out:
# [1.   2.   3.   4.   5.1  1.78]
# float64

# %%
new3=new3.astype(int)
new3
# Out:
# array([1, 2, 3, 4, 5, 1])

# %%
print(new3.dtype)
# Out:
# int64

# %%
new4=np.array([-1,1,0,0,3,4])
print(new4)
# Out:
# [-1  1  0  0  3  4]

# %%
new4=new4.astype(bool)

# %%
new4
# Out:
# array([ True,  True, False, False,  True,  True])
