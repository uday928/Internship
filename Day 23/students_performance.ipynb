# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('students (5).csv')

# %%
df.head(10)
# Out:
#    stu_id gender  maths  science  computer  operating systems  total  \
# 0      47      F     88       84        82                 86    340
# 1      48      M     76       72        74                 78    300
# 2      49      F     65       67        62                 60    254
# 3      50      M     55       58        52                 50    215
# 4      51      F     45       42        48                 44    179
# 5      52      M     39       85        78                 80    282
# 6      53      F     92       38        88                 91    309
# 7      54      M     40       41        42                 43    166
# 8      55      F     81       79        83                 85    328
# 9      56      M     90       91        89                 88    358
#
#    percentage grade result
# 0          85     A   PASS
# 1          75     B   PASS
# 2          64     C   PASS
# 3          54     D   PASS
# 4          45     E   PASS
# 5          71     F   FAIL
# ...

# %%
df.tail(10)
# Out:
#      stu_id gender  maths  science  computer  operating systems  total  \
# 188     235      M     30       25        35                 30    120
# 189     236      F     30       25        35                 30    120
# 190     237      M     30       25        35                 30    120
# 191     238      F     30       25        35                 30    120
# 192     239      M     30       25        35                 30    120
# 193     240      F     30       25        35                 30    120
# 194     241      M     30       25        35                 30    120
# 195     242      F     30       25        35                 30    120
# 196     243      M     30       25        35                 30    120
# 197     244      F     30       25        35                 30    120
#
#      percentage grade result
# 188          30     F   FAIL
# 189          30     F   FAIL
# 190          30     F   FAIL
# 191          30     F   FAIL
# 192          30     F   FAIL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   stu_id             198 non-null    int64
#  1   gender             198 non-null    object
#  2   maths              198 non-null    int64
#  3   science            198 non-null    int64
#  4   computer           198 non-null    int64
#  5   operating systems  198 non-null    int64
#  6   total              198 non-null    int64
#  7   percentage         198 non-null    int64
#  8   grade              198 non-null    object
#  9   result             198 non-null    object
# dtypes: int64(7), object(3)
# memory usage: 15.6+ KB

# %%
df.shape
# Out:
# (198, 10)

# %%
df.describe()
# Out:
#            stu_id       maths     science    computer  operating systems  \
# count  198.000000  198.000000  198.000000  198.000000         198.000000
# mean   145.500000   64.454545   66.818182   68.626263          68.303030
# std     57.301832   20.506417   20.488632   17.490584          19.270163
# min     47.000000   20.000000   25.000000   35.000000          30.000000
# 25%     96.250000   49.250000   56.250000   56.250000          56.250000
# 50%    145.500000   70.000000   74.000000   72.000000          71.000000
# 75%    194.750000   80.000000   82.000000   85.000000          82.500000
# max    244.000000   97.000000   96.000000   96.000000          95.000000
#
#             total  percentage
# count  198.000000  198.000000
# mean   268.202020   67.191919
# std     74.260207   18.559099
# min    120.000000   30.000000
# 25%    222.250000   56.000000
# 50%    288.000000   72.000000
# 75%    328.000000   82.000000
# max    382.000000   96.000000

# %%
df['result'].value_counts()
# Out:
# result
# PASS    162
# FAIL     36
# Name: count, dtype: int64

# %%
df['grade'].value_counts()
# Out:
# grade
# A    38
# F    36
# B    34
# C    34
# D    34
# E    16
# O     6
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# F    100
# M     98
# Name: count, dtype: int64

# %%
df[df['result']=='FAIL']
# Out:
#      stu_id gender  maths  science  computer  operating systems  total  \
# 5        52      M     39       85        78                 80    282
# 6        53      F     92       38        88                 91    309
# 14       61      F     30       35        60                 65    190
# 20       67      F     25       70        75                 80    250
# 27       74      M     38       39        70                 75    222
# 34       81      F     32       60        70                 75    237
# 40       87      F     20       80        85                 90    275
# 47       94      M     37       75        80                 85    277
# 54      101      M     39       85        78                 80    282
# 55      102      F     92       38        88                 91    309
# 63      110      F     30       35        60                 65    190
# 69      116      F     25       70        75                 80    250
# ...

# %%
df[df['grade']=='F']
# Out:
#      stu_id gender  maths  science  computer  operating systems  total  \
# 5        52      M     39       85        78                 80    282
# 6        53      F     92       38        88                 91    309
# 14       61      F     30       35        60                 65    190
# 20       67      F     25       70        75                 80    250
# 27       74      M     38       39        70                 75    222
# 34       81      F     32       60        70                 75    237
# 40       87      F     20       80        85                 90    275
# 47       94      M     37       75        80                 85    277
# 54      101      M     39       85        78                 80    282
# 55      102      F     92       38        88                 91    309
# 63      110      F     30       35        60                 65    190
# 69      116      F     25       70        75                 80    250
# ...

# %%
mean_by_gender = df.groupby('gender')[['maths','science','computer','operating systems','percentage']].mean()
mean_by_gender
# Out:
#             maths    science   computer  operating systems  percentage
# gender
# F       64.240000  66.520000  68.760000          68.740000   67.200000
# M       64.673469  67.122449  68.489796          67.857143   67.183673

# %%
columns=['maths',	'science',	'computer',	'operating systems']

# %%
sns.heatmap(data=df[columns].corr(),annot=True,cmap='Blues')
# There is no negative corrections
# Out:
# <Axes: >

# %%
# Students who has O grade:
passdf=df[df['grade']!='F']
passdf
# Out:
#      stu_id gender  maths  science  computer  operating systems  total  \
# 0        47      F     88       84        82                 86    340
# 1        48      M     76       72        74                 78    300
# 2        49      F     65       67        62                 60    254
# 3        50      M     55       58        52                 50    215
# 4        51      F     45       42        48                 44    179
# ..      ...    ...    ...      ...       ...                ...    ...
# 173     220      F     60       62        65                 61    248
# 174     221      M     60       62        65                 61    248
# 175     222      F     60       62        65                 61    248
# 176     223      M     60       62        65                 61    248
# 177     224      F     60       62        65                 61    248
#
#      percentage grade result
# 0            85     A   PASS
# 1            75     B   PASS
# ...

# %%
# histogram
sns.histplot(data=df, x="percentage",kde=True)
# Out:
# <Axes: xlabel='percentage', ylabel='Count'>

# %%
# box plot
sns.boxplot(data=df, x="gender", y="percentage")
# Out:
# <Axes: xlabel='gender', ylabel='percentage'>

# %%
sns.barplot(data=df, x="grade", y="maths",hue='gender',errorbar=None)
# Out:
# <Axes: xlabel='grade', ylabel='maths'>

# %%
sns.barplot(data=df, x="grade", y="science",hue='gender',errorbar=None)
# Out:
# <Axes: xlabel='grade', ylabel='science'>

# %%
sns.barplot(data=df, x="grade", y="operating systems",hue='gender',errorbar=None)
# Out:
# <Axes: xlabel='grade', ylabel='operating systems'>

# %%
sns.barplot(data=df, x="grade", y="computer",hue='gender',errorbar=None)
# Out:
# <Axes: xlabel='grade', ylabel='computer'>

# %%
passdf.head(10)
# Out:
#     stu_id gender  maths  science  computer  operating systems  total  \
# 0       47      F     88       84        82                 86    340
# 1       48      M     76       72        74                 78    300
# 2       49      F     65       67        62                 60    254
# 3       50      M     55       58        52                 50    215
# 4       51      F     45       42        48                 44    179
# 7       54      M     40       41        42                 43    166
# 8       55      F     81       79        83                 85    328
# 9       56      M     90       91        89                 88    358
# 10      57      F     72       75        71                 73    291
# 11      58      M     61       63        66                 64    254
#
#     percentage grade result
# 0           85     A   PASS
# 1           75     B   PASS
# 2           64     C   PASS
# 3           54     D   PASS
# 4           45     E   PASS
# ...

# %%
# Out:
#             maths    science   computer  operating systems  percentage
# gender
# F       64.240000  66.520000  68.760000          68.740000   67.200000
# M       64.673469  67.122449  68.489796          67.857143   67.183673

# %%
score_df = df[['maths','science','computer','operating systems']]
score_df
# Out:
#      maths  science  computer  operating systems
# 0       88       84        82                 86
# 1       76       72        74                 78
# 2       65       67        62                 60
# 3       55       58        52                 50
# 4       45       42        48                 44
# ..     ...      ...       ...                ...
# 193     30       25        35                 30
# 194     30       25        35                 30
# 195     30       25        35                 30
# 196     30       25        35                 30
# 197     30       25        35                 30
#
# [198 rows x 4 columns]

# %%
sns.boxplot(data=score_df)
# Out:
# <Axes: >

# %%
# students failed in all subjects:
failed_all = df[
    (df["maths"] < 40) &
    (df["science"] < 40) &
    (df["computer"] < 40) &
    (df["operating systems"] < 40)
]

print("This students failed in all subjects:")
failed_all.shape[0]
# Out:
# This students failed in all subjects:
# 20

# %%
failed_all
# Out:
#      stu_id gender  maths  science  computer  operating systems  total  \
# 178     225      M     30       25        35                 30    120
# 179     226      F     30       25        35                 30    120
# 180     227      M     30       25        35                 30    120
# 181     228      F     30       25        35                 30    120
# 182     229      M     30       25        35                 30    120
# 183     230      F     30       25        35                 30    120
# 184     231      M     30       25        35                 30    120
# 185     232      F     30       25        35                 30    120
# 186     233      M     30       25        35                 30    120
# 187     234      F     30       25        35                 30    120
# 188     235      M     30       25        35                 30    120
# 189     236      F     30       25        35                 30    120
# ...

# %%
sns.pairplot(df[['maths','science','computer','operating systems']])

# %%
sns.histplot(data=df,x='grade',hue='gender',multiple='stack')
# Out:
# <Axes: xlabel='grade', ylabel='Count'>
