# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import mysql.connector as cnc

# %%
conn = cnc.connect(
    host="localhost",
    user="root",
    password="",
    database="students_evaluation"
)

cursor = conn.cursor()

cursor.execute("SELECT * FROM students")

for row in cursor.fetchall():
    print(row)

conn.close()
# Out:
# (47, 'Student_2', 20, 'F', 88, 84, 82, 86, 340, Decimal('85'), 'A', 'PASS')
# (48, 'Student_3', 18, 'M', 76, 72, 74, 78, 300, Decimal('75'), 'B', 'PASS')
# (49, 'Student_4', 21, 'F', 65, 67, 62, 60, 254, Decimal('64'), 'C', 'PASS')
# (50, 'Student_5', 19, 'M', 55, 58, 52, 50, 215, Decimal('54'), 'D', 'PASS')
# (51, 'Student_6', 22, 'F', 45, 42, 48, 44, 179, Decimal('45'), 'E', 'PASS')
# (52, 'Student_7', 20, 'M', 39, 85, 78, 80, 282, Decimal('71'), 'F', 'FAIL')
# (53, 'Student_8', 19, 'F', 92, 38, 88, 91, 309, Decimal('77'), 'F', 'FAIL')
# (54, 'Student_9', 18, 'M', 40, 41, 42, 43, 166, Decimal('42'), 'E', 'PASS')
# (55, 'Student_10', 21, 'F', 81, 79, 83, 85, 328, Decimal('82'), 'A', 'PASS')
# (56, 'Student_11', 20, 'M', 90, 91, 89, 88, 358, Decimal('90'), 'A', 'PASS')
# (57, 'Student_12', 18, 'F', 72, 75, 71, 73, 291, Decimal('73'), 'B', 'PASS')
# (58, 'Student_13', 19, 'M', 61, 63, 66, 64, 254, Decimal('64'), 'C', 'PASS')
# (59, 'Student_14', 22, 'F', 50, 52, 49, 51, 202, Decimal('51'), 'D', 'PASS')
# (60, 'Student_15', 21, 'M', 41, 44, 40, 43, 168, Decimal('42'), 'E', 'PASS')
# (61, 'Student_16', 20, 'F', 30, 35, 60, 65, 190, Decimal('48'), 'F', 'FAIL')
# (62, 'Student_17', 19, 'M', 85, 88, 90, 92, 355, Decimal('89'), 'A', 'PASS')
# (63, 'Student_18', 18, 'F', 77, 79, 75, 74, 305, Decimal('76'), 'B', 'PASS')
# (64, 'Student_19', 22, 'M', 68, 69, 66, 65, 268, Decimal('67'), 'C', 'PASS')
# (65, 'Student_20', 21, 'F', 59, 57, 54, 55, 225, Decimal('56'), 'D', 'PASS')
# (66, 'Student_21', 20, 'M', 48, 45, 47, 49, 189, Decimal('47'), 'E', 'PASS')
# (67, 'Student_22', 19, 'F', 25, 70, 75, 80, 250, Decimal('63'), 'F', 'FAIL')
# (68, 'Student_23', 18, 'M', 93, 94, 96, 95, 378, Decimal('95'), 'O', 'PASS')
# (69, 'Student_24', 22, 'F', 82, 81, 80, 83, 326, Decimal('82'), 'A', 'PASS')
# (70, 'Student_25', 21, 'M', 74, 76, 72, 70, 292, Decimal('73'), 'B', 'PASS')
# (71, 'Student_26', 20, 'F', 64, 62, 60, 63, 249, Decimal('62'), 'C', 'PASS')
# (72, 'Student_27', 19, 'M', 53, 55, 52, 50, 210, Decimal('53'), 'D', 'PASS')
# (73, 'Student_28', 18, 'F', 46, 48, 45, 47, 186, Decimal('47'), 'E', 'PASS')
# (74, 'Student_29', 22, 'M', 38, 39, 70, 75, 222, Decimal('56'), 'F', 'FAIL')
# (75, 'Student_30', 21, 'F', 88, 90, 85, 87, 350, Decimal('88'), 'A', 'PASS')
# (76, 'Student_31', 20, 'M', 91, 93, 89, 90, 363, Decimal('91'), 'O', 'PASS')
# (77, 'Student_32', 19, 'F', 79, 78, 77, 76, 310, Decimal('78'), 'B', 'PASS')
# (78, 'Student_33', 18, 'M', 67, 65, 66, 64, 262, Decimal('66'), 'C', 'PASS')
# (79, 'Student_34', 22, 'F', 56, 58, 55, 54, 223, Decimal('56'), 'D', 'PASS')
# (80, 'Student_35', 21, 'M', 44, 42, 45, 43, 174, Decimal('44'), 'E', 'PASS')
# (81, 'Student_36', 20, 'F', 32, 60, 70, 75, 237, Decimal('59'), 'F', 'FAIL')
# (82, 'Student_37', 19, 'M', 84, 82, 86, 88, 340, Decimal('85'), 'A', 'PASS')
# (83, 'Student_38', 18, 'F', 73, 71, 74, 72, 290, Decimal('73'), 'B', 'PASS')
# (84, 'Student_39', 22, 'M', 62, 60, 63, 61, 246, Decimal('62'), 'C', 'PASS')
# (85, 'Student_40', 21, 'F', 51, 53, 52, 54, 210, Decimal('53'), 'D', 'PASS')
# (86, 'Student_41', 20, 'M', 47, 46, 48, 45, 186, Decimal('47'), 'E', 'PASS')
# (87, 'Student_42', 19, 'F', 20, 80, 85, 90, 275, Decimal('69'), 'F', 'FAIL')
# (88, 'Student_43', 18, 'M', 97, 96, 95, 94, 382, Decimal('96'), 'O', 'PASS')
# (89, 'Student_44', 22, 'F', 83, 85, 82, 84, 334, Decimal('84'), 'A', 'PASS')
# (90, 'Student_45', 21, 'M', 75, 74, 72, 73, 294, Decimal('74'), 'B', 'PASS')
# (91, 'Student_46', 20, 'F', 66, 68, 65, 67, 266, Decimal('67'), 'C', 'PASS')
# (92, 'Student_47', 19, 'M', 54, 56, 53, 55, 218, Decimal('55'), 'D', 'PASS')
# (93, 'Student_48', 18, 'F', 49, 47, 46, 48, 190, Decimal('48'), 'E', 'PASS')
# (94, 'Student_49', 22, 'M', 37, 75, 80, 85, 277, Decimal('69'), 'F', 'FAIL')
# (95, 'Student_50', 21, 'F', 89, 87, 90, 88, 354, Decimal('89'), 'A', 'PASS')
# (96, 'Student_2', 20, 'F', 88, 84, 82, 86, 340, Decimal('85'), 'A', 'PASS')
# (97, 'Student_3', 18, 'M', 76, 72, 74, 78, 300, Decimal('75'), 'B', 'PASS')
# (98, 'Student_4', 21, 'F', 65, 67, 62, 60, 254, Decimal('64'), 'C', 'PASS')
# (99, 'Student_5', 19, 'M', 55, 58, 52, 50, 215, Decimal('54'), 'D', 'PASS')
# (100, 'Student_6', 22, 'F', 45, 42, 48, 44, 179, Decimal('45'), 'E', 'PASS')
# (101, 'Student_7', 20, 'M', 39, 85, 78, 80, 282, Decimal('71'), 'F', 'FAIL')
# (102, 'Student_8', 19, 'F', 92, 38, 88, 91, 309, Decimal('77'), 'F', 'FAIL')
# (103, 'Student_9', 18, 'M', 40, 41, 42, 43, 166, Decimal('42'), 'E', 'PASS')
# (104, 'Student_10', 21, 'F', 81, 79, 83, 85, 328, Decimal('82'), 'A', 'PASS')
# (105, 'Student_11', 20, 'M', 90, 91, 89, 88, 358, Decimal('90'), 'A', 'PASS')
# (106, 'Student_12', 18, 'F', 72, 75, 71, 73, 291, Decimal('73'), 'B', 'PASS')
# (107, 'Student_13', 19, 'M', 61, 63, 66, 64, 254, Decimal('64'), 'C', 'PASS')
# (108, 'Student_14', 22, 'F', 50, 52, 49, 51, 202, Decimal('51'), 'D', 'PASS')
# (109, 'Student_15', 21, 'M', 41, 44, 40, 43, 168, Decimal('42'), 'E', 'PASS')
# (110, 'Student_16', 20, 'F', 30, 35, 60, 65, 190, Decimal('48'), 'F', 'FAIL')
# (111, 'Student_17', 19, 'M', 85, 88, 90, 92, 355, Decimal('89'), 'A', 'PASS')
# (112, 'Student_18', 18, 'F', 77, 79, 75, 74, 305, Decimal('76'), 'B', 'PASS')
# (113, 'Student_19', 22, 'M', 68, 69, 66, 65, 268, Decimal('67'), 'C', 'PASS')
# (114, 'Student_20', 21, 'F', 59, 57, 54, 55, 225, Decimal('56'), 'D', 'PASS')
# (115, 'Student_21', 20, 'M', 48, 45, 47, 49, 189, Decimal('47'), 'E', 'PASS')
# (116, 'Student_22', 19, 'F', 25, 70, 75, 80, 250, Decimal('63'), 'F', 'FAIL')
# (117, 'Student_23', 18, 'M', 93, 94, 96, 95, 378, Decimal('95'), 'O', 'PASS')
# (118, 'Student_24', 22, 'F', 82, 81, 80, 83, 326, Decimal('82'), 'A', 'PASS')
# (119, 'Student_25', 21, 'M', 74, 76, 72, 70, 292, Decimal('73'), 'B', 'PASS')
# (120, 'Student_26', 20, 'F', 64, 62, 60, 63, 249, Decimal('62'), 'C', 'PASS')
# (121, 'Student_27', 19, 'M', 53, 55, 52, 50, 210, Decimal('53'), 'D', 'PASS')
# (122, 'Student_28', 18, 'F', 46, 48, 45, 47, 186, Decimal('47'), 'E', 'PASS')
# (123, 'Student_29', 22, 'M', 38, 39, 70, 75, 222, Decimal('56'), 'F', 'FAIL')
# (124, 'Student_30', 21, 'F', 88, 90, 85, 87, 350, Decimal('88'), 'A', 'PASS')
# (125, 'Student_31', 20, 'M', 91, 93, 89, 90, 363, Decimal('91'), 'O', 'PASS')
# (126, 'Student_32', 19, 'F', 79, 78, 77, 76, 310, Decimal('78'), 'B', 'PASS')
# (127, 'Student_33', 18, 'M', 67, 65, 66, 64, 262, Decimal('66'), 'C', 'PASS')
# (128, 'Student_34', 22, 'F', 56, 58, 55, 54, 223, Decimal('56'), 'D', 'PASS')
# (129, 'Student_35', 21, 'M', 44, 42, 45, 43, 174, Decimal('44'), 'E', 'PASS')
# (130, 'Student_36', 20, 'F', 32, 60, 70, 75, 237, Decimal('59'), 'F', 'FAIL')
# (131, 'Student_37', 19, 'M', 84, 82, 86, 88, 340, Decimal('85'), 'A', 'PASS')
# (132, 'Student_38', 18, 'F', 73, 71, 74, 72, 290, Decimal('73'), 'B', 'PASS')
# (133, 'Student_39', 22, 'M', 62, 60, 63, 61, 246, Decimal('62'), 'C', 'PASS')
# (134, 'Student_40', 21, 'F', 51, 53, 52, 54, 210, Decimal('53'), 'D', 'PASS')
# (135, 'Student_41', 20, 'M', 47, 46, 48, 45, 186, Decimal('47'), 'E', 'PASS')
# (136, 'Student_42', 19, 'F', 20, 80, 85, 90, 275, Decimal('69'), 'F', 'FAIL')
# (137, 'Student_43', 18, 'M', 97, 96, 95, 94, 382, Decimal('96'), 'O', 'PASS')
# (138, 'Student_44', 22, 'F', 83, 85, 82, 84, 334, Decimal('84'), 'A', 'PASS')
# (139, 'Student_45', 21, 'M', 75, 74, 72, 73, 294, Decimal('74'), 'B', 'PASS')
# (140, 'Student_46', 20, 'F', 66, 68, 65, 67, 266, Decimal('67'), 'C', 'PASS')
# (141, 'Student_47', 19, 'M', 54, 56, 53, 55, 218, Decimal('55'), 'D', 'PASS')
# (142, 'Student_48', 18, 'F', 49, 47, 46, 48, 190, Decimal('48'), 'E', 'PASS')
# (143, 'Student_49', 22, 'M', 37, 75, 80, 85, 277, Decimal('69'), 'F', 'FAIL')
# (144, 'Student_50', 21, 'F', 89, 87, 90, 88, 354, Decimal('89'), 'A', 'PASS')
# (145, 'Student 1', 18, 'M', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (146, 'Student 2', 19, 'F', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (147, 'Student 3', 20, 'M', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (148, 'Student 4', 21, 'F', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (149, 'Student 5', 22, 'M', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (150, 'Student 6', 18, 'F', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (151, 'Student 7', 19, 'M', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (152, 'Student 8', 20, 'F', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (153, 'Student 9', 21, 'M', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (154, 'Student 10', 22, 'F', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (155, 'Student 11', 18, 'M', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (156, 'Student 12', 19, 'F', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (157, 'Student 13', 20, 'M', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (158, 'Student 14', 21, 'F', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (159, 'Student 15', 22, 'M', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (160, 'Student 16', 18, 'F', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (161, 'Student 17', 19, 'M', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (162, 'Student 18', 20, 'F', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (163, 'Student 19', 21, 'M', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (164, 'Student 20', 22, 'F', 90, 92, 88, 94, 364, Decimal('91'), 'A', 'PASS')
# (165, 'Student 21', 18, 'M', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (166, 'Student 22', 19, 'F', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (167, 'Student 23', 20, 'M', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (168, 'Student 24', 21, 'F', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (169, 'Student 25', 22, 'M', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (170, 'Student 26', 18, 'F', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (171, 'Student 27', 19, 'M', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (172, 'Student 28', 20, 'F', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (173, 'Student 29', 21, 'M', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (174, 'Student 30', 22, 'F', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (175, 'Student 31', 18, 'M', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (176, 'Student 32', 19, 'F', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (177, 'Student 33', 20, 'M', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (178, 'Student 34', 21, 'F', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (179, 'Student 35', 22, 'M', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (180, 'Student 36', 18, 'F', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (181, 'Student 37', 19, 'M', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (182, 'Student 38', 20, 'F', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (183, 'Student 39', 21, 'M', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (184, 'Student 40', 22, 'F', 80, 82, 85, 81, 328, Decimal('82'), 'B', 'PASS')
# (185, 'Student 41', 18, 'M', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (186, 'Student 42', 19, 'F', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (187, 'Student 43', 20, 'M', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (188, 'Student 44', 21, 'F', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (189, 'Student 45', 22, 'M', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (190, 'Student 46', 18, 'F', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (191, 'Student 47', 19, 'M', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (192, 'Student 48', 20, 'F', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (193, 'Student 49', 21, 'M', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (194, 'Student 50', 22, 'F', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (195, 'Student 51', 18, 'M', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (196, 'Student 52', 19, 'F', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (197, 'Student 53', 20, 'M', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (198, 'Student 54', 21, 'F', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (199, 'Student 55', 22, 'M', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (200, 'Student 56', 18, 'F', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (201, 'Student 57', 19, 'M', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (202, 'Student 58', 20, 'F', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (203, 'Student 59', 21, 'M', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (204, 'Student 60', 22, 'F', 70, 75, 72, 71, 288, Decimal('72'), 'C', 'PASS')
# (205, 'Student 61', 18, 'M', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (206, 'Student 62', 19, 'F', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (207, 'Student 63', 20, 'M', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (208, 'Student 64', 21, 'F', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (209, 'Student 65', 22, 'M', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (210, 'Student 66', 18, 'F', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (211, 'Student 67', 19, 'M', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (212, 'Student 68', 20, 'F', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (213, 'Student 69', 21, 'M', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (214, 'Student 70', 22, 'F', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (215, 'Student 71', 18, 'M', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (216, 'Student 72', 19, 'F', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (217, 'Student 73', 20, 'M', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (218, 'Student 74', 21, 'F', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (219, 'Student 75', 22, 'M', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (220, 'Student 76', 18, 'F', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (221, 'Student 77', 19, 'M', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (222, 'Student 78', 20, 'F', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (223, 'Student 79', 21, 'M', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (224, 'Student 80', 22, 'F', 60, 62, 65, 61, 248, Decimal('62'), 'D', 'PASS')
# (225, 'Student 81', 18, 'M', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (226, 'Student 82', 19, 'F', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (227, 'Student 83', 20, 'M', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (228, 'Student 84', 21, 'F', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (229, 'Student 85', 22, 'M', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (230, 'Student 86', 18, 'F', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (231, 'Student 87', 19, 'M', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (232, 'Student 88', 20, 'F', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (233, 'Student 89', 21, 'M', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (234, 'Student 90', 22, 'F', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (235, 'Student 91', 18, 'M', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (236, 'Student 92', 19, 'F', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (237, 'Student 93', 20, 'M', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (238, 'Student 94', 21, 'F', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (239, 'Student 95', 22, 'M', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (240, 'Student 96', 18, 'F', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (241, 'Student 97', 19, 'M', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (242, 'Student 98', 20, 'F', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (243, 'Student 99', 21, 'M', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')
# (244, 'Student 100', 22, 'F', 30, 25, 35, 30, 120, Decimal('30'), 'F', 'FAIL')

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqlconnector://root:password@localhost/students_evaluation")

df = pd.read_sql("SELECT * FROM students", engine)

print(df.head(10))
# Out:
#    stu_id        name  age gender  maths  science  computer  \
# 0      47   Student_2   20      F     88       84        82
# 1      48   Student_3   18      M     76       72        74
# 2      49   Student_4   21      F     65       67        62
# 3      50   Student_5   19      M     55       58        52
# 4      51   Student_6   22      F     45       42        48
# 5      52   Student_7   20      M     39       85        78
# 6      53   Student_8   19      F     92       38        88
# 7      54   Student_9   18      M     40       41        42
# 8      55  Student_10   21      F     81       79        83
# 9      56  Student_11   20      M     90       91        89
#
#    operating systems  total  percentage grade result
# 0                 86    340        85.0     A   PASS
# 1                 78    300        75.0     B   PASS
# 2                 60    254        64.0     C   PASS
# 3                 50    215        54.0     D   PASS
# 4                 44    179        45.0     E   PASS
# 5                 80    282        71.0     F   FAIL
# 6                 91    309        77.0     F   FAIL
# 7                 43    166        42.0     E   PASS
# 8                 85    328        82.0     A   PASS
# 9                 88    358        90.0     A   PASS
